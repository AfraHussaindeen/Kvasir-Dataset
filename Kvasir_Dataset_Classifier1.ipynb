# %%
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D,Dense,MaxPool2D,Conv2D,Flatten
from keras.applications import DenseNet201
from keras.models import Model
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/My Drive/Projects/Colab Notebooks/pchallenge2.zip"

# %%
train_dataAugmentation = ImageDataGenerator(
  #  rotation_range=180,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=(0.5,0.9),
    # shear_range=45,
    zoom_range=[0.8,1.2],
    horizontal_flip=True,
    vertical_flip=True,
    rescale=1./255,
    fill_mode='nearest',
    )

test_dataAugmentation = ImageDataGenerator(rescale=1./255)

train_data_generator=train_dataAugmentation.flow_from_directory('pchallenge2/train',
                                                 target_size=(200,200),
                                                 color_mode='rgb',
                                                 batch_size=32,
                                                 class_mode='categorical',
                                                 shuffle=True)

test_data_generator =test_dataAugmentation.flow_from_directory('pchallenge2/validation',
                                        target_size=(200,200),
                                       batch_size=50,
                                       class_mode='categorical')
# Out:
# Found 5700 images belonging to 8 classes.
# Found 2300 images belonging to 8 classes.

# %%
train_data_generator.class_indices
# Out:
# {'dyed-lifted-polyps': 0,
#  'dyed-resection-margins': 1,
#  'esophagitis': 2,
#  'normal-cecum': 3,
#  'normal-pylorus': 4,
#  'normal-z-line': 5,
#  'polyps': 6,
#  'ulcerative-colitis': 7}

# %%
class_indices ={0:"dyed-lifted-polyps",1:"dyed-resection-margins",2:"esophagitis",3:"normal-cecum",4:"normal-pylorus",5:"normal-z-line",6:"polyps",7:"ulcerative-colitis"}

plt.figure(figsize=(10, 10))
for X_batch, y_batch in train_data_generator:
  for i in range(9):
    image=X_batch[i]
    ax = plt.subplot(3,3, i + 1)
    plt.imshow(image)
    plt.title(class_indices[list(y_batch[i]).index(1.0)])
    plt.axis("off")
  break

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,\
     Dropout,Flatten,Dense,Activation,\
     BatchNormalization
model=Sequential()

model.add(Conv2D(32,(3,3),activation='relu',padding='same',input_shape=(200,200,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128,(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128,(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(256,(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(1024,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512,activation='relu'))
model.add(Dense(8,activation='softmax'))

model.compile(loss='categorical_crossentropy',
  optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit_generator (steps_per_epoch=(train_data_generator.n//train_data_generator.batch_size),
                               generator=train_data_generator,
                               validation_data=test_data_generator,
                               validation_steps=test_data_generator.n//test_data_generator.batch_size,
                               epochs=100)
# Out:
# Epoch 1/100
# 178/178 [==============================] - 167s 940ms/step - loss: 1.2524 - accuracy: 0.5441 - val_loss: 9.4388 - val_accuracy: 0.1304
# Epoch 2/100
# 178/178 [==============================] - 166s 935ms/step - loss: 0.7962 - accuracy: 0.6401 - val_loss: 2.2442 - val_accuracy: 0.2887
# Epoch 3/100
# 178/178 [==============================] - 166s 931ms/step - loss: 0.7423 - accuracy: 0.6535 - val_loss: 0.7692 - val_accuracy: 0.5596
# Epoch 4/100
# 178/178 [==============================] - 166s 930ms/step - loss: 0.7005 - accuracy: 0.6736 - val_loss: 0.7130 - val_accuracy: 0.5474
# Epoch 5/100
# 178/178 [==============================] - 165s 929ms/step - loss: 0.6717 - accuracy: 0.6909 - val_loss: 0.8260 - val_accuracy: 0.5809
# Epoch 63/100
# 178/178 [==============================] - 173s 970ms/step - loss: 0.2335 - accuracy: 0.9055 - val_loss: 0.1394 - val_accuracy: 0.8604
# Epoch 64/100
# 178/178 [==============================] - 171s 963ms/step - loss: 0.2506 - accuracy: 0.9007 - val_loss: 0.1467 - val_accuracy: 0.8657
# Epoch 65/100
# 178/178 [==============================] - 173s 972ms/step - loss: 0.2094 - accuracy: 0.9133 - val_loss: 0.1993 - val_accuracy: 0.8700
# Epoch 66/100
# 178/178 [==============================] - 173s 971ms/step - loss: 0.2256 - accuracy: 0.9097 - val_loss: 0.5780 - val_accuracy: 0.8361
# Epoch 67/100
# 178/178 [==============================] - 171s 959ms/step - loss: 0.2221 - accuracy: 0.9108 - val_loss: 0.2724 - val_accuracy: 0.8700
# Epoch 68/100
# 178/178 [==============================] - 170s 953ms/step - loss: 0.2099 - accuracy: 0.9102 - val_loss: 0.2766 - val_accuracy: 0.8470
# Epoch 69/100
# 178/178 [==============================] - 169s 952ms/step - loss: 0.2253 - accuracy: 0.9051 - val_loss: 0.3786 - val_accuracy: 0.8565
# Epoch 70/100
# 178/178 [==============================] - 175s 984ms/step - loss: 0.2204 - accuracy: 0.9095 - val_loss: 0.4457 - val_accuracy: 0.8722
# Epoch 71/100
# 178/178 [==============================] - 173s 971ms/step - loss: 0.2173 - accuracy: 0.9105 - val_loss: 0.2844 - val_accuracy: 0.8626
# Epoch 72/100
# 178/178 [==============================] - 171s 962ms/step - loss: 0.2231 - accuracy: 0.9062 - val_loss: 0.5084 - val_accuracy: 0.8504
# Epoch 73/100
# 178/178 [==============================] - 174s 975ms/step - loss: 0.2158 - accuracy: 0.9142 - val_loss: 0.3136 - val_accuracy: 0.8139
# Epoch 74/100
# 178/178 [==============================] - 173s 972ms/step - loss: 0.2242 - accuracy: 0.9135 - val_loss: 0.4299 - val_accuracy: 0.8683
# Epoch 75/100
# 178/178 [==============================] - 176s 988ms/step - loss: 0.2158 - accuracy: 0.9093 - val_loss: 0.3500 - val_accuracy: 0.8665
# Epoch 76/100
# 178/178 [==============================] - 176s 991ms/step - loss: 0.1959 - accuracy: 0.9156 - val_loss: 0.2226 - val_accuracy: 0.8739
# Epoch 77/100
# 178/178 [==============================] - 173s 973ms/step - loss: 0.2078 - accuracy: 0.9168 - val_loss: 0.1809 - val_accuracy: 0.8896
# Epoch 78/100
# 178/178 [==============================] - 174s 977ms/step - loss: 0.2085 - accuracy: 0.9143 - val_loss: 0.6682 - val_accuracy: 0.8565
# Epoch 79/100
# 178/178 [==============================] - 174s 979ms/step - loss: 0.2059 - accuracy: 0.9149 - val_loss: 0.3746 - val_accuracy: 0.8587
# Epoch 80/100
# 178/178 [==============================] - 172s 969ms/step - loss: 0.2062 - accuracy: 0.9160 - val_loss: 0.4415 - val_accuracy: 0.8548
# Epoch 81/100
# 178/178 [==============================] - 175s 984ms/step - loss: 0.2091 - accuracy: 0.9105 - val_loss: 0.7486 - val_accuracy: 0.8343
# Epoch 82/100
# 178/178 [==============================] - 171s 961ms/step - loss: 0.1983 - accuracy: 0.9223 - val_loss: 0.8181 - val_accuracy: 0.8448
# Epoch 83/100
# 178/178 [==============================] - 174s 976ms/step - loss: 0.1917 - accuracy: 0.9226 - val_loss: 0.2204 - val_accuracy: 0.8883
# Epoch 84/100
# 178/178 [==============================] - 173s 969ms/step - loss: 0.1956 - accuracy: 0.9170 - val_loss: 0.7533 - val_accuracy: 0.8048
# Epoch 85/100
# 178/178 [==============================] - 170s 954ms/step - loss: 0.2041 - accuracy: 0.9158 - val_loss: 0.5763 - val_accuracy: 0.8739
# Epoch 86/100
# 178/178 [==============================] - 169s 950ms/step - loss: 0.1924 - accuracy: 0.9238 - val_loss: 0.5734 - val_accuracy: 0.8709
# Epoch 87/100
# 178/178 [==============================] - 169s 952ms/step - loss: 0.1972 - accuracy: 0.9164 - val_loss: 0.6809 - val_accuracy: 0.8826
# Epoch 88/100
# 178/178 [==============================] - 168s 946ms/step - loss: 0.1691 - accuracy: 0.9271 - val_loss: 0.2824 - val_accuracy: 0.8861
# Epoch 89/100
# 178/178 [==============================] - 174s 975ms/step - loss: 0.1787 - accuracy: 0.9263 - val_loss: 0.3105 - val_accuracy: 0.8652
# Epoch 90/100
# 178/178 [==============================] - 175s 981ms/step - loss: 0.1930 - accuracy: 0.9225 - val_loss: 0.3450 - val_accuracy: 0.8722
# Epoch 91/100
# 178/178 [==============================] - 174s 977ms/step - loss: 0.1872 - accuracy: 0.9224 - val_loss: 0.4485 - val_accuracy: 0.8213
# Epoch 92/100
# 178/178 [==============================] - 172s 969ms/step - loss: 0.1629 - accuracy: 0.9291 - val_loss: 0.4678 - val_accuracy: 0.8548
# Epoch 93/100
# 178/178 [==============================] - 177s 992ms/step - loss: 0.1810 - accuracy: 0.9294 - val_loss: 0.2341 - val_accuracy: 0.8539
# Epoch 94/100
# 178/178 [==============================] - 176s 988ms/step - loss: 0.1840 - accuracy: 0.9215 - val_loss: 0.3529 - val_accuracy: 0.8709
# Epoch 95/100
# 178/178 [==============================] - 173s 974ms/step - loss: 0.1965 - accuracy: 0.9216 - val_loss: 0.2671 - val_accuracy: 0.8591
# Epoch 96/100
# 178/178 [==============================] - 175s 981ms/step - loss: 0.1820 - accuracy: 0.9228 - val_loss: 0.5046 - val_accuracy: 0.8487
# Epoch 97/100
# 178/178 [==============================] - 172s 969ms/step - loss: 0.1832 - accuracy: 0.9289 - val_loss: 0.4927 - val_accuracy: 0.8639
# Epoch 98/100
# 178/178 [==============================] - 173s 972ms/step - loss: 0.1948 - accuracy: 0.9241 - val_loss: 0.4470 - val_accuracy: 0.8565
# Epoch 99/100
# 178/178 [==============================] - 171s 962ms/step - loss: 0.1811 - accuracy: 0.9285 - val_loss: 0.5856 - val_accuracy: 0.8239
# Epoch 100/100
# 178/178 [==============================] - 175s 982ms/step - loss: 0.1685 - accuracy: 0.9291 - val_loss: 0.6310 - val_accuracy: 0.7743

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(100)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
